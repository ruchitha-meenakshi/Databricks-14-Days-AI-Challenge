# %%
# Direct loading (Clean & Simple)
base_path = "/Volumes/workspace/ecommerce/ecommerce_data/processed_data"

# %% [markdown]
# ###### Loading Data

# %%
# Load the October data
oct_events = spark.read.parquet(f"{base_path}/oct_2019")

# If we ever need a sample
# df_sample = df_combined.sample(fraction=0.1, seed=42)

print(f"✅ Loaded October Data: {oct_events.count():,} rows")
# Out:
# ✅ Loaded October Data: 42,448,764 rows

# %%
oct_events.show(2)
# Out:
# +-------------------+----------+----------+-------------------+--------------------+-----+------+---------+--------------------+
# |         event_time|event_type|product_id|        category_id|       category_code|brand| price|  user_id|        user_session|
# +-------------------+----------+----------+-------------------+--------------------+-----+------+---------+--------------------+
# |2019-10-13 06:25:46|      view|   1002544|2053013555631882655|electronics.smart...|apple|460.51|518958788|e7e27c5c-1e78-481...|
# |2019-10-13 06:25:46|      view|   3700301|2053013565983425517|appliances.enviro...|vitek|120.93|557977070|7afc206c-7259-4be...|
# +-------------------+----------+----------+-------------------+--------------------+-----+------+---------+--------------------+
# only showing top 2 rows

# %% [markdown]
# #### Practice

# %%
# Create simple DataFrame
data = [("iPhone", 999), ("Samsung", 799), ("MacBook", 1299)]
df = spark.createDataFrame(data, ["product", "price"])
df.show()

# Filter expensive products
df.filter(df.price > 1000).show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# | iPhone|  999|
# |Samsung|  799|
# |MacBook| 1299|
# +-------+-----+
#
# +-------+-----+
# |product|price|
# +-------+-----+
# |MacBook| 1299|
# +-------+-----+
